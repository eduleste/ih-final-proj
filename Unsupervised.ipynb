# %%
import pandas as pd 


breadbasket = pd.read_csv("~/Downloads/BreadBasket_DMS.csv")
print(breadbasket.shape)
breadbasket.head()
# Out:
# (21293, 4)
#          Date      Time  Transaction           Item
# 0  2016-10-30  09:58:11            1          Bread
# 1  2016-10-30  10:05:34            2   Scandinavian
# 2  2016-10-30  10:05:34            2   Scandinavian
# 3  2016-10-30  10:07:57            3  Hot chocolate
# 4  2016-10-30  10:07:57            3            Jam

# %%
breadbasket['DateTime'] = pd.to_datetime(breadbasket.Date + ' ' + breadbasket.Time)
len(breadbasket.Item.unique())
# Out:
# Coffee                           5471
# Bread                            3325
# Tea                              1435
# Cake                             1025
# Pastry                            856
# NONE                              786
# Sandwich                          771
# Medialuna                         616
# Hot chocolate                     590
# Cookies                           540
# Brownie                           379
# Farm House                        374
# Muffin                            370
# Juice                             369
# Alfajores                         369
# Soup                              342
# Scone                             327
# Toast                             318
# Scandinavian                      277
# Truffles                          193
# Coke                              185
# Spanish Brunch                    172
# Fudge                             159
# Baguette                          152
# Jam                               149
# Tiffin                            146
# Mineral water                     136
# Jammie Dodgers                    125
# Chicken Stew                      123
# Hearty & Seasonal                 107
#                                  ...
# Empanadas                           7
# Argentina Night                     7
# Honey                               6
# Pintxos                             6
# Crepes                              6
# Basket                              6
# Lemon and coconut                   6
# Half slice Monster                  6
# Bare Popcorn                        5
# Panatone                            5
# Mortimer                            5
# Bread Pudding                       4
# Brioche and salami                  3
# Raspberry shortbread sandwich       3
# Caramel bites                       3
# Cherry me Dried fruit               3
# Fairy Doors                         2
# Bowl Nic Pitt                       2
# Chimichurri Oil                     2
# Hack the stack                      2
# Siblings                            2
# Spread                              2
# Adjustment                          1
# Polenta                             1
# Bacon                               1
# The BART                            1
# Olum & polenta                      1
# Gift voucher                        1
# Chicken sand                        1
# Raw bars                            1
# Name: Item, Length: 95, dtype: int64

# %%
categories = {
    'beverage':['Hot chocolate', 'Coffee', 'Tea', 'Mineral water', 'Juice', 'Coke', 'Smoothies'],
    'kids':["Ella's Kitchen Pouches", 'My-5 Fruit Shoot', 'Kids biscuit'],
    'snacks':['Mighty Protein', 'Pick and Mix Bowls', 'Caramel bites', 'Bare Popcorn', 'Crisps', 'Cherry me Dried fruit', 'Raw bars'],
    'bread':['Bread', 'Toast', 'Baguette', 'Focaccia', 'Scandinavian'],
    'breakfast_pastry':['Muffin', 'Pastry', 'Medialuna', 'Scone'],
    'dessert':['Cookies', 'Tartine', 'Fudge', 'Victorian Sponge', 'Cake', 'Alfajores', 'Brownie', 'Bread Pudding', 'Bakewell', 'Raspberry shortbread sandwich', 'Lemon and coconut', 'Crepes', 'Chocolates', 'Truffles', 'Panatone'],
    'condiments':['Jam', 'Dulce de Leche', 'Honey', 'Gingerbread syrup', 'Extra Salami or Feta', 'Bacon', 'Spread', 'Chimichurri Oil'],
    'breakfast':['Eggs', 'Frittata', 'Granola', 'Muesli', 'Duck egg', 'Brioche and salami'],
    'lunch':['Soup', 'Sandwich', 'Chicken sand', 'Salad', 'Chicken Stew'],
}

categorized = [c for k in categories.keys() for c in categories[k]]
categories['others'] = [x for x in breadbasket.Item.unique() if x not in categorized]

# %%
import numpy as np

for cat in categories.keys():
    breadbasket[cat] = np.where(breadbasket.Item.isin(categories[cat]), 1, 0)

# %%
breadbasket.head()
breadbasket = breadbasket.drop(columns=["Date","Time"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33
# 9680                        0        0           0          0      0       0
# 9681                        0        1           0          0      0       2
# 9682                        1        0           0          0      0       1
# 9683                        1        0           0          0      0       0
# 9684                        0        0           0          0      0       0
#
# [9531 rows x 11 columns]

# %%
bread_group['hour'] = bread_group.DateTime.dt.hour
bread_group['day'] = bread_group.DateTime.dt.day_name()
display(bread_group.head())
display(bread_group.day.value_counts())
display(bread_group.hour.value_counts())
# Out:
#                        DateTime  beverage  kids  snacks  bread  \
# Transaction
# 1           2016-10-30 09:58:11         0     0       0      1
# 2           2016-10-30 10:05:34         0     0       0      2
# 3           2016-10-30 10:07:57         1     0       0      0
# 4           2016-10-30 10:08:41         0     0       0      0
# 5           2016-10-30 10:13:03         1     0       0      1
#
#              breakfast_pastry  dessert  condiments  breakfast  lunch  others  \
# Transaction
# 1                           0        0           0          0      0       0
# 2                           0        0           0          0      0       0
# 3                           0        1           1          0      0       0
# 4                           1        0           0          0      0       0
# 5                           1        0           0          0      0       0
#
#              hour     day
# Transaction
# 1               9  Sunday
# 2              10  Sunday
# 3              10  Sunday
# 4              10  Sunday
# 5              10  Sunday
# Saturday     2068
# Friday       1488
# Sunday       1264
# Thursday     1252
# Tuesday      1203
# Monday       1135
# Wednesday    1121
# Name: day, dtype: int64
# 11    1445
# 12    1347
# 10    1267
# 13    1163
# 14    1130
# 9     1007
# 15     924
# 16     583
# 8      375
# 17     160
# 18      52
# 19      34
# 7       16
# 20      15
# 22       7
# 23       3
# 21       2
# 1        1
# Name: hour, dtype: int64

# %%
bread_days = pd.get_dummies(data=bread_group, columns=['day'])
bread_days.drop(columns='DateTime', inplace=True, axis=1)

# %%
bread_days.head()
bread_days.shape
# Out:
# (9531, 18)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=4)

principalComponents = pca.fit_transform(bread_days)
principalDf = pd.DataFrame(data = principalComponents
             ,columns = ['pc1', 'pc2', 'pc3', 'pc4'])
principalDf.head()
# Out:
#         pc1       pc2       pc3       pc4
# 0  3.197989 -0.931700  0.237573 -0.068287
# 1  2.228491 -1.280402  1.067450 -0.515340
# 2  2.108209  0.418718  0.072186  0.908976
# 3  2.199539 -0.586069 -0.680365  0.230756
# 4  2.207388  0.030175  0.384724 -0.435591

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5)
bread_clusters = kmeans.fit(principalDf)
bread_clusters.cluster_centers_
# Out:
# array([[-1.38721530e+00, -1.49178845e-01, -6.54538119e-02,
#          2.62259407e-02],
#        [ 9.87639343e-01, -5.57609156e-01,  6.37410969e-02,
#          2.04605805e-02],
#        [-3.60446951e+00, -2.11630793e-02,  4.88304333e-02,
#         -2.46746165e-03],
#        [ 2.93826822e+00,  7.95924769e-02, -5.21318921e-02,
#          1.37913085e-02],
#        [ 2.44036509e-01,  1.03777785e+00,  2.96887692e-02,
#         -9.81300377e-02]])

# %%
bread_days['labels'] = bread_clusters.fit_predict(principalDf)
bread_days.reset_index('Transaction', inplace=True)
bread_merged = pd.merge(breadbasket, bread_days[['Transaction', 'labels']], on='Transaction', how='outer')
bread_merged.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-123dac00e93f> in <module>
#       1 bread_days['labels'] = bread_clusters.fit_predict(principalDf)
# ----> 2 bread_days.reset_index('Transaction', inplace=True)
#       3 bread_merged = pd.merge(breadbasket, bread_days[['Transaction', 'labels']], on='Transaction', how='outer')
#       4 bread_merged.head()
#       5
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4392             if not isinstance(level, (tuple, list)):
#    4393                 level = [level]
# -> 4394             level = [self.index._get_level_number(lev) for lev in level]
#    4395             if len(level) < self.index.nlevels:
#    4396                 new_index = self.index.droplevel(level)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in <listcomp>(.0)
#    4392             if not isinstance(level, (tuple, list)):
#    4393                 level = [level]
# -> 4394             level = [self.index._get_level_number(lev) for lev in level]
#    4395             if len(level) < self.index.nlevels:
#    4396                 new_index = self.index.droplevel(level)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in _get_level_number(self, level)
#    1424
#    1425     def _get_level_number(self, level):
# -> 1426         self._validate_index_level(level)
#    1427         return 0
#    1428
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in _validate_index_level(self, level)
#    1421         elif level != self.name:
#    1422             raise KeyError('Level %s must be same as name (%s)' %
# -> 1423                            (level, self.name))
#    1424
#    1425     def _get_level_number(self, level):
#
# KeyError: 'Level Transaction must be same as name (None)'

# %%
bread_merged.labels.value_counts()
# Out:
# 3    5172
# 2    5144
# 1    4041
# 4    3755
# 0    3181
# Name: labels, dtype: int64

# %%
pd.crosstab(bread_days.hour,bread_days.labels)
# Out:
# labels     0     1    2     3    4
# hour
# 1          0     1    0     0    0
# 7          0    16    0     0    0
# 8          0   375    0     0    0
# 9          0   982   25     0    0
# 10         0  1004  263     0    0
# 11         0     0  334  1111    0
# 12         0     0  267  1080    0
# 13      1130     0   33     0    0
# 14      1128     0    2     0    0
# 15         0     0    0     0  924
# 16         0     0    0     0  583
# 17         0     0    0     0  160
# 18         0     0    0     0   52
# 19         0     0    0     0   34
# 20         0     0    0     0   15
# 21         0     0    0     0    2
# 22         0     0    0     0    7
# 23         0     0    0     0    3

# %%
pd.crosstab(bread_group.day,bread_days.labels)
# Out:
# labels       0    1    2    3    4
# day
# Friday     355  326  160  358  269
# Monday     250  315   95  243  232
# Saturday   506  393  224  441  411
# Sunday     304  295  127  297  209
# Thursday   264  387  120  287  194
# Tuesday    271  300  116  293  223
# Wednesday  283  329   71  225  213

# %%
a = bread_merged.groupby(['labels']).Item.value_counts()
b = a.to_frame("counts").reset_index()
b.set_index("Item", inplace=True)
b.groupby('labels').counts.nlargest(5)
# Out:
# labels  Item
# 0       Bread             975
#         Coffee            382
#         NONE              153
#         Sandwich          140
#         Cake              122
# 1       Coffee            927
#         Bread             560
#         Tea               382
#         Cake              328
#         Hot chocolate     183
# 2       Coffee           2074
#         Tea               410
#         Bread             280
#         Pastry            250
#         NONE              204
# 3       Coffee           1243
#         Bread             486
#         Tea               413
#         Sandwich          392
#         Cake              299
# 4       Bread            1024
#         Coffee            845
#         Pastry            337
#         Medialuna         223
#         Tea               136
# Name: counts, dtype: int64
